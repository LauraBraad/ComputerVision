# %%
import json
import pandas as pd

# %%
path = './coco-labels-paper.txt'
labels = pd.read_csv(path)
labels['category_id'] = labels.index

# %%
pred = open('./yolov7_predictions.json')
pred = pd.read_json(pred)

# %%
pred['category_id_new'] = pred['category_id'] - 1

# %%
pred_mean = pred.groupby("category_id_new").agg({'score': ['count', 'mean']})

# %%
merged_df = pd.merge(pred_mean, labels, left_on = 'category_id_new', right_on = 'category_id' , how='inner')

# Display the merged DataFrame
merged_df
# Out:
# /Users/laurabraadrasmussen/opt/anaconda3/envs/slml/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left,1 on the right)
#   """Entry point for launching an IPython kernel.
#     (score, count)  (score, mean)      Labels  category_id
# 0           103367       0.094511      person            0
# 1             7775       0.039196     bicycle            1
# 2            29844       0.060149         car            2
# 3             5422       0.062442  motorcycle            3
# 4             1889       0.075009    airplane            4
# ..             ...            ...         ...          ...
# 75            5562       0.050084        vase           85
# 76            1426       0.020224    scissors           86
# 77            2307       0.072701  teddy bear           87
# 78             663       0.010789  hair drier           88
# ...

# %%
list(merged_df.columns)
# Out:
# [('score', 'count'), ('score', 'mean'), 'Labels', 'category_id']

# %%
pred_mean['score']['mean'].argmin()
# Out:
# 78

# %%
pred_mean['score']['mean'].argmax()
# Out:
# 20

# %%
merged_df.iloc[78]
# Out:
# (score, count)           663
# (score, mean)       0.010789
# Labels            hair drier
# category_id               88
# Name: 78, dtype: object

# %%
import matplotlib.pyplot as plt
plt.plot(merged_df['Labels'])
